# %%
import time

n = int(input("Enter number of elements: "))
arr = list(map(int, input("Enter elements: ").split()))

start = time.time()

for i in range(n - 1):
    for j in range(n - i - 1):
        if arr[j] > arr[j + 1]:
            arr[j], arr[j + 1] = arr[j + 1], arr[j]

end = time.time()

print("Sorted Array:", arr)
print("Time Complexity: O(n²)")
print("Execution Time:", end - start, "seconds")
# Out:
# Enter number of elements: 5
# Enter elements: 1 2 4 3 5
# Sorted Array: [1, 2, 3, 4, 5]
# Time Complexity: O(n²)
# Execution Time: 0.00015997886657714844 seconds

# %%
import time

def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        left = arr[:mid]
        right = arr[mid:]

        merge_sort(left)
        merge_sort(right)

        i = j = k = 0

        while i < len(left) and j < len(right):
            if left[i] < right[j]:
                arr[k] = left[i]
                i += 1
            else:
                arr[k] = right[j]
                j += 1
            k += 1

        while i < len(left):
            arr[k] = left[i]
            i += 1
            k += 1

        while j < len(right):
            arr[k] = right[j]
            j += 1
            k += 1

n = int(input("Enter number of elements: "))
arr = list(map(int, input("Enter elements: ").split()))

start = time.time()

merge_sort(arr)

end = time.time()

print("Sorted Array:", arr)
print("Time Complexity: O(n log n)")
print("Execution Time:", end - start, "seconds")
# Out:
# Enter number of elements: 6
# Enter elements: 1 4 5 2 3 6
# Sorted Array: [1, 2, 3, 4, 5, 6]
# Time Complexity: O(n log n)
# Execution Time: 0.0001461505889892578 seconds

# %%
import time

n = int(input("Enter number of elements: "))
arr = list(map(int, input("Enter elements: ").split()))

start = time.time()

for i in range(n):
    min = i
    for j in range(i + 1, n):
        if arr[j] < arr[min]:
            min = j
    arr[i], arr[min] = arr[min], arr[i]

end = time.time()

print("Sorted Array:", arr)
print("Time Complexity: O(n²)")
print("Execution Time:", end - start, "seconds")
# Out:
# Enter number of elements: 8
# Enter elements: 7 4 1 8 5 2 6 3
# Sorted Array: [1, 2, 3, 4, 5, 6, 7, 8]
# Time Complexity: O(n²)
# Execution Time: 0.00023603439331054688 seconds

# %%
import time

n = int(input("Enter number of elements: "))
arr = list(map(int, input("Enter elements: ").split()))

start = time.time()

for i in range(1, n):
    key = arr[i]
    j = i - 1
    while j >= 0 and arr[j] > key:
        arr[j + 1] = arr[j]
        j -= 1
    arr[j + 1] = key

end = time.time()

print("Sorted Array:", arr)
print("Time Complexity: O(n²)")
print("Execution Time:", end - start, "seconds")
# Out:
# Enter number of elements: 6
# Enter elements: 1 4 2 5 3 6
# Sorted Array: [1, 2, 3, 4, 5, 6]
# Time Complexity: O(n²)
# Execution Time: 0.00020956993103027344 seconds

# %%
import time

def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[0]
    left = [x for x in arr[1:] if x <= pivot]
    right = [x for x in arr[1:] if x > pivot]
    return quick_sort(left) + [pivot] + quick_sort(right)

n = int(input("Enter number of elements: "))
arr = list(map(int, input("Enter elements: ").split()))

start = time.time()

arr = quick_sort(arr)

end = time.time()

print("Sorted Array:", arr)
print("Time Complexity: O(n log n)")
print("Execution Time:", end - start, "seconds")
# Out:
# Enter number of elements: 5
# Enter elements: 1 4 5 2 3
# Sorted Array: [1, 2, 3, 4, 5]
# Time Complexity: O(n log n)
# Execution Time: 9.942054748535156e-05 seconds
