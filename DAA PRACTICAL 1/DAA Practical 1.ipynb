# %%
import time

n = int(input("Enter number of elements: "))
arr = list(map(int, input("Enter elements: ").split()))

start = time.perf_counter()

# Selection Sort
for i in range(n):
    min_idx = i
    for j in range(i + 1, n):
        if arr[j] < arr[min_idx]:
            min_idx = j
    arr[i], arr[min_idx] = arr[min_idx], arr[i]

end = time.perf_counter()

print("Sorted Array:", arr)
print("Execution Time:", end - start, "seconds")
print("Time Complexity: Best = O(n²), Average = O(n²), Worst = O(n²)")
# Out:
# Enter number of elements: 5
# Enter elements: 1  9 4 6 7
# Sorted Array: [1, 4, 6, 7, 9]
# Execution Time: 0.0003829250000535467 seconds
# Time Complexity: Best = O(n²), Average = O(n²), Worst = O(n²)

# %%
import time

n = int(input("Enter number of elements: "))
arr = list(map(int, input("Enter elements: ").split()))

start = time.perf_counter()

# Insertion Sort
for i in range(1, n):
    key = arr[i]
    j = i - 1
    while j >= 0 and arr[j] > key:
        arr[j + 1] = arr[j]
        j -= 1
    arr[j + 1] = key

end = time.perf_counter()

print("Sorted Array:", arr)
print("Execution Time:", end - start, "seconds")
print("Time Complexity: Best = O(n), Average = O(n²), Worst = O(n²)")
# Out:
# Enter number of elements: 4
# Enter elements: 1 9 6 4
# Sorted Array: [1, 4, 6, 9]
# Execution Time: 0.0002112209999722836 seconds
# Time Complexity: Best = O(n), Average = O(n²), Worst = O(n²)

# %%
import time

n = int(input("Enter number of elements: "))
arr = list(map(int, input("Enter elements: ").split()))

start = time.perf_counter()

# Bubble Sort
for i in range(n):
    for j in range(0, n - i - 1):
        if arr[j] > arr[j + 1]:
            arr[j], arr[j + 1] = arr[j + 1], arr[j]

end = time.perf_counter()

print("Sorted Array:", arr)
print("Execution Time:", end - start, "seconds")
print("Time Complexity: Best = O(n), Average = O(n²), Worst = O(n²)")
# Out:
# Enter number of elements: 3
# Enter elements: 1 8 4
# Sorted Array: [1, 4, 8]
# Execution Time: 0.0002951369999664166 seconds
# Time Complexity: Best = O(n), Average = O(n²), Worst = O(n²)

# %%
import time

def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    mid = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick_sort(left) + mid + quick_sort(right)

n = int(input("Enter number of elements: "))
arr = list(map(int, input("Enter elements: ").split()))

start = time.perf_counter()
arr = quick_sort(arr)
end = time.perf_counter()

print("Sorted Array:", arr)
print("Execution Time:", end - start, "seconds")
print("Time Complexity: Best = O(n log n), Average = O(n log n), Worst = O(n²)")
# Out:
# Enter number of elements: 6
# Enter elements: 1 9 5 4 7 3
# Sorted Array: [1, 3, 4, 5, 7, 9]
# Execution Time: 0.00016816400011521182 seconds
# Time Complexity: Best = O(n log n), Average = O(n log n), Worst = O(n²)

# %%
import time

def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        left = arr[:mid]
        right = arr[mid:]

        merge_sort(left)
        merge_sort(right)

        i = j = k = 0
        while i < len(left) and j < len(right):
            if left[i] < right[j]:
                arr[k] = left[i]
                i += 1
            else:
                arr[k] = right[j]
                j += 1
            k += 1

        while i < len(left):
            arr[k] = left[i]
            i += 1
            k += 1

        while j < len(right):
            arr[k] = right[j]
            j += 1
            k += 1

n = int(input("Enter number of elements: "))
arr = list(map(int, input("Enter elements: ").split()))

start = time.perf_counter()
merge_sort(arr)
end = time.perf_counter()

print("Sorted Array:", arr)
print("Execution Time:", end - start, "seconds")
print("Time Complexity: Best = O(n log n), Average = O(n log n), Worst = O(n log n)")
# Out:
# Enter number of elements: 5
# Enter elements: 1 6 8 4 9
# Sorted Array: [1, 4, 6, 8, 9]
# Execution Time: 0.00014437300001191034 seconds
# Time Complexity: Best = O(n log n), Average = O(n log n), Worst = O(n log n)
