# %%
import time

n = int(input("Enter a number: "))

start = time.perf_counter()

fact = 1
for i in range(1, n + 1):
    fact *= i

end = time.perf_counter()

print("Factorial =", fact)
print("Execution time:", end - start, "seconds")
print("Time Complexity: O(n)")
# Out:
# Enter a number: 4
# Factorial = 24
# Execution time: 0.00015332299994952336 seconds
# Time Complexity: O(n)

# %%
import time

def factorial(n):
    if n == 0 or n == 1:
        return 1
    return n * factorial(n - 1)

n = int(input("Enter a number: "))

start = time.perf_counter()

fact = factorial(n)

end = time.perf_counter()

print("Factorial =", fact)
print("Execution time:", end - start, "seconds")
print("Time Complexity: O(n)")
# Out:
# Enter a number: 6
# Factorial = 720
# Execution time: 0.0001423209999984465 seconds
# Time Complexity: O(n)
